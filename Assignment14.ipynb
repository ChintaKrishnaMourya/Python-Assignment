# %% [markdown]
# # These are answers to the given questions.

# %% [markdown]
# ### 1. What does RGBA stand for?
#
# RGBA stands for Red Green Blue Alpha. It is a color model used to represent colors in computer graphics and images.

# %% [markdown]
# ### 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from PIL import ImageColor,Image
img=Image.open(r"C:\Users\koush\Downloads\ceraxces.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1192x670>

# %%
import numpy as np
np.array(img)
# Out:
# array([[[ 18,  20,  17],
#         [ 19,  21,  18],
#         [ 19,  21,  18],
#         ...,
#         [  9,  11,  10],
#         [ 10,  12,  11],
#         [ 10,  12,  11]],
#
#        [[ 18,  20,  17],
#         [ 19,  21,  18],
#         [ 19,  21,  18],
#         ...,
#         [  9,  11,  10],
#         [ 10,  12,  11],
#         [ 10,  12,  11]],
#
#        [[ 18,  20,  17],
#         [ 19,  21,  18],
#         [ 19,  21,  18],
#         ...,
#         [  9,  11,  10],
#         [ 10,  12,  11],
#         [ 10,  12,  11]],
#
#        ...,
#
#        [[122, 108,  81],
#         [118, 104,  78],
#         [116, 102,  76],
#         ...,
#         [ 51,  53,  48],
#         [ 56,  58,  53],
#         [ 57,  59,  54]],
#
#        [[122, 108,  81],
#         [119, 105,  79],
#         [117, 103,  77],
#         ...,
#         [ 56,  58,  53],
#         [ 59,  61,  56],
#         [ 58,  60,  55]],
#
#        [[122, 108,  81],
#         [120, 106,  80],
#         [120, 106,  80],
# ...

# %%
rgba = img.getpixel((90, 90))

# Print the RGBA value
print(rgba)
# Out:
# (22, 32, 34)

# %% [markdown]
# ### 3. What is a box tuple, and how does it work?
# In pillow module, a box tuple is a that represents a rectangular region in an image. It is a tuple of four integers - (left, upper, right, lower). Each represents the co ordinate position of rectange.
#
# (100,50,50,150) --> left cordinate 100, upper cordinate 50, right co ordinate 50,  lower co ordinate 150.

# %% [markdown]
# ### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
img=Image.open(r"C:\Users\koush\Downloads\ceraxces.jpg")
width, height = img.size
width, height
# Out:
# (1192, 670)

# %% [markdown]
# ### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
#
# we use crop method from image

# %%
from PIL import Image
img=Image.open(r"C:\Users\koush\OneDrive\Desktop\R.png")
box = (0,50,50,100)
excluding_lower_left = img.crop(box)

# %% [markdown]
# ### 6. After making changes to an Image object, how could you save it as an image file?
#
# by using save() method of image object

# %%
excluding_lower_left.save("excluding_lower_left.png")

# %% [markdown]
# ### 7. What module contains Pillow’s shape-drawing code?
#
# ImageDraw module pillow's shape-drawing code

# %% [markdown]
# ### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
#
# We have to use ImageDraw object. To get this object, we have call "ImageDraw.Draw()" method.

# %%
from PIL import Image, ImageDraw

draw = ImageDraw.Draw(image)
